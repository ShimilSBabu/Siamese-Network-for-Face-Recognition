# %% [markdown]
# # Importing Libs

# %%
from sklearn.datasets import fetch_olivetti_faces
from numpy.random import RandomState
import numpy as np
import cv2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Conv2D, Dense, MaxPooling2D, Input, Flatten, Dropout, GlobalAveragePooling2D, Lambda
import tensorflow as tf
import tensorflow.keras.backend as k
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# # Defining the Constants

# %%
model_save_name = 'custom_loss_function_in_siamese_network'

# %% [markdown]
# # Importing the Dataset

# %%
rng = RandomState(0)
# images_dataset, labels_dataset = fetch_olivetti_faces(return_X_y=True, shuffle=True, random_state=rng)
data = fetch_olivetti_faces(return_X_y=False, shuffle=True, random_state=rng)
images_dataset = data['images']
labels_dataset = data['target']
# n_samples, n_features = images_dataset.shape

# %% [markdown]
# # Functions

# %% [markdown]
# ## Function to Display Images

# %%
def display_images(image1, image2):
  f, axarr = plt.subplots(1,2)
  # plt.figure()
  axarr[0].imshow(image1)
  axarr[1].imshow(image2)
  # plt.colorbar()
  plt.grid(False)
  plt.show()

# def display_images(image):
#   plt.figure()
#   plt.imshow(image)
#   plt.colorbar()
#   plt.grid(False)
#   plt.show()

# %% [markdown]
# ## Function to Save the Model

# %%
def save_model(model_save_name):
  current_time = str(datetime.now())[:16].replace(':', '_')
  model.save(f'{model_save_name}_{current_time}.h5')

# %% [markdown]
# ## Function to Calculate Euclidian Distance

# %%
def euclidean_distance(vectors):
    (featA, featB) = vectors
    sum_squared = k.sum(k.square(featA - featB), axis=1, keepdims=True)
    return k.sqrt(k.maximum(sum_squared, k.epsilon()))

# %% [markdown]
# ## Function for Training Pairs Generation

# %%
def generate_train_image_pairs(images_dataset, labels_dataset):
    unique_labels = np.unique(labels_dataset)
    label_wise_indices = dict()
    for label in unique_labels:
        label_wise_indices.setdefault(label,
                                      [index for index, curr_label in enumerate(labels_dataset) if
                                       label == curr_label])
    
    pair_images = []
    pair_labels = []
    for index, image in enumerate(images_dataset):
        pos_indices = label_wise_indices.get(labels_dataset[index])
        pos_image = images_dataset[np.random.choice(pos_indices)]
        
        image = cv2.resize(image, dsize=(64, 64))
        
        pair_images.append((image, pos_image))
        pair_labels.append(1)

        neg_indices = np.where(labels_dataset != labels_dataset[index])
        neg_image = images_dataset[np.random.choice(neg_indices[0])]
        pair_images.append((image, neg_image))
        pair_labels.append(0)
    pair_labels = np.array(pair_labels)
    pair_labels = pair_labels.astype('float32')  
    return np.array(pair_images), np.array(pair_labels)

# %% [markdown]
# ## Function for Testing Pairs Generation

# %%
def generate_test_image_pairs(images_dataset, labels_dataset, image):
    unique_labels = np.unique(labels_dataset)
    label_wise_indices = dict()
    for label in unique_labels:
        label_wise_indices.setdefault(label,
                                      [index for index, curr_label in enumerate(labels_dataset) if
                                        label == curr_label])
  
    pair_images = []
    pair_labels = []
    for label, indices_for_label in label_wise_indices.items():
        test_image = images_dataset[np.random.choice(indices_for_label)]
        pair_images.append((image, test_image))
        pair_labels.append(label)
    pair_labels = np.array(pair_labels)
    pair_labels = pair_labels.astype('float32')  
    return np.array(pair_images), np.array(pair_labels)

# %% [markdown]
# ## Custom Loss Function

# %%
def contrastive_loss_with_margin(margin = 1):
  def contrastive_loss(y_true, y_pred):
    square_pred = k.square(y_pred)
    margin_square = k.square(k.maximum(margin - y_pred, 0))
    return k.mean(y_true * square_pred + (1 - y_true) * margin_square)
  return contrastive_loss

# %% [markdown]
# ## Function to Define the Model

# %%
def create_model():
    inputs = Input((64, 64, 1))
    x = Conv2D(96, (11, 11), padding="same", activation="relu")(inputs)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)

    x = Conv2D(256, (5, 5), padding="same", activation="relu")(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)

    x = Conv2D(384, (3, 3), padding="same", activation="relu")(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)

    pooledOutput = GlobalAveragePooling2D()(x)
    pooledOutput = Dense(1024)(pooledOutput)
    outputs = Dense(128)(pooledOutput)

    model = Model(inputs, outputs)
    return model

# %% [markdown]
# # Generating Training Image Pairs

# %%
images_pair, labels_pair = generate_train_image_pairs(images_dataset, labels_dataset)

# %% [markdown]
# # Display Some Image Pairs

# %%
image_pair_num = 3
display_images(images_pair[image_pair_num][0], images_pair[image_pair_num][1])
print(labels_pair[image_pair_num])
# Out:
# 0.0

# %% [markdown]
# # Feature Extraction

# %%
feature_extractor = create_model()
imgA = Input(shape=(64, 64, 1))
imgB = Input(shape=(64, 64, 1))
featA = feature_extractor(imgA)
featB = feature_extractor(imgB)

# %% [markdown]
# # Generating the Model

# %%
distance = Lambda(euclidean_distance)([featA, featB])
outputs = Dense(1, activation="sigmoid")(distance)
model = Model(inputs=[imgA, imgB], outputs=outputs)

# %% [markdown]
# # Compiling the Model

# %%
model.compile(loss = contrastive_loss_with_margin(margin = 0.5), optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# # Plotting the Model

# %%
plot_model(model, show_shapes=True, show_layer_names=True, to_file= f'{model_save_name}.png')

# %% [markdown]
# # Plotting the Model (Simpler View)

# %%
plot_model(model)

# %% [markdown]
# # Training the Model

# %%
history = model.fit([images_pair[:, 0], images_pair[:, 1]], labels_pair[:],validation_split=0.1,batch_size=64,epochs=100)
# Out:
# Epoch 1/100
#
# 12/12 [==============================] - 2s 112ms/step - loss: 0.0639 - accuracy: 0.3583 - val_loss: 0.0588 - val_accuracy: 0.5000
#
# Epoch 2/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0570 - accuracy: 0.4931 - val_loss: 0.0567 - val_accuracy: 0.5000
#
# Epoch 3/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0556 - accuracy: 0.4292 - val_loss: 0.0557 - val_accuracy: 0.5000
#
# Epoch 4/100
#
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0541 - accuracy: 0.4681 - val_loss: 0.0550 - val_accuracy: 0.5000
#
# Epoch 5/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0538 - accuracy: 0.4389 - val_loss: 0.0566 - val_accuracy: 0.4375
#
# Epoch 6/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0521 - accuracy: 0.4417 - val_loss: 0.0540 - val_accuracy: 0.5000
#
# Epoch 7/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0512 - accuracy: 0.4319 - val_loss: 0.0538 - val_accuracy: 0.5000
#
# Epoch 8/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0511 - accuracy: 0.4431 - val_loss: 0.0536 - val_accuracy: 0.5000
#
# Epoch 9/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0509 - accuracy: 0.4556 - val_loss: 0.0528 - val_accuracy: 0.5000
#
# Epoch 10/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0499 - accuracy: 0.4208 - val_loss: 0.0527 - val_accuracy: 0.5000
#
# Epoch 11/100
#
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0506 - accuracy: 0.4542 - val_loss: 0.0534 - val_accuracy: 0.5000
#
# Epoch 12/100
#
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0493 - accuracy: 0.4222 - val_loss: 0.0527 - val_accuracy: 0.5000
#
# Epoch 13/100
#
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0483 - accuracy: 0.4222 - val_loss: 0.0531 - val_accuracy: 0.5000
#
# Epoch 14/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0479 - accuracy: 0.4542 - val_loss: 0.0527 - val_accuracy: 0.5000
#
# Epoch 15/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0480 - accuracy: 0.3708 - val_loss: 0.0534 - val_accuracy: 0.5000
#
# Epoch 16/100
#
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0480 - accuracy: 0.4444 - val_loss: 0.0507 - val_accuracy: 0.5000
#
# Epoch 17/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0468 - accuracy: 0.4097 - val_loss: 0.0509 - val_accuracy: 0.5000
#
# Epoch 18/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0465 - accuracy: 0.4097 - val_loss: 0.0506 - val_accuracy: 0.5000
#
# Epoch 19/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0467 - accuracy: 0.4167 - val_loss: 0.0506 - val_accuracy: 0.5000
#
# Epoch 20/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0459 - accuracy: 0.3819 - val_loss: 0.0507 - val_accuracy: 0.5000
#
# Epoch 21/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0450 - accuracy: 0.4056 - val_loss: 0.0490 - val_accuracy: 0.5000
#
# Epoch 22/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0453 - accuracy: 0.3986 - val_loss: 0.0482 - val_accuracy: 0.5000
#
# Epoch 23/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0441 - accuracy: 0.3889 - val_loss: 0.0501 - val_accuracy: 0.5000
#
# Epoch 24/100
#
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0441 - accuracy: 0.4125 - val_loss: 0.0476 - val_accuracy: 0.5000
#
# Epoch 25/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0435 - accuracy: 0.4028 - val_loss: 0.0479 - val_accuracy: 0.4875
#
# Epoch 26/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0433 - accuracy: 0.3736 - val_loss: 0.0477 - val_accuracy: 0.4875
#
# Epoch 27/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0434 - accuracy: 0.4014 - val_loss: 0.0472 - val_accuracy: 0.5000
#
# Epoch 28/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0429 - accuracy: 0.4083 - val_loss: 0.0487 - val_accuracy: 0.4875
#
# Epoch 29/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0431 - accuracy: 0.3528 - val_loss: 0.0491 - val_accuracy: 0.5000
#
# Epoch 30/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0414 - accuracy: 0.4014 - val_loss: 0.0443 - val_accuracy: 0.4875
#
# Epoch 31/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0418 - accuracy: 0.3556 - val_loss: 0.0464 - val_accuracy: 0.5000
#
# Epoch 32/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0408 - accuracy: 0.3611 - val_loss: 0.0468 - val_accuracy: 0.4875
#
# Epoch 33/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0417 - accuracy: 0.4000 - val_loss: 0.0454 - val_accuracy: 0.5000
#
# Epoch 34/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0403 - accuracy: 0.3625 - val_loss: 0.0459 - val_accuracy: 0.5000
#
# Epoch 35/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0395 - accuracy: 0.3764 - val_loss: 0.0415 - val_accuracy: 0.4875
#
# Epoch 36/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0401 - accuracy: 0.3514 - val_loss: 0.0449 - val_accuracy: 0.5000
#
# Epoch 37/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0394 - accuracy: 0.3583 - val_loss: 0.0429 - val_accuracy: 0.4875
#
# Epoch 38/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0389 - accuracy: 0.3597 - val_loss: 0.0433 - val_accuracy: 0.4875
#
# Epoch 39/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0384 - accuracy: 0.3347 - val_loss: 0.0423 - val_accuracy: 0.4875
#
# Epoch 40/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0392 - accuracy: 0.3486 - val_loss: 0.0434 - val_accuracy: 0.5000
#
# Epoch 41/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0380 - accuracy: 0.3667 - val_loss: 0.0407 - val_accuracy: 0.4750
#
# Epoch 42/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0375 - accuracy: 0.3153 - val_loss: 0.0426 - val_accuracy: 0.5000
#
# Epoch 43/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0365 - accuracy: 0.3611 - val_loss: 0.0406 - val_accuracy: 0.4875
#
# Epoch 44/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0364 - accuracy: 0.3333 - val_loss: 0.0428 - val_accuracy: 0.4875
#
# Epoch 45/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0363 - accuracy: 0.3375 - val_loss: 0.0428 - val_accuracy: 0.4875
#
# Epoch 46/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0365 - accuracy: 0.3542 - val_loss: 0.0420 - val_accuracy: 0.4875
#
# Epoch 47/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0363 - accuracy: 0.3264 - val_loss: 0.0427 - val_accuracy: 0.5000
#
# Epoch 48/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0356 - accuracy: 0.3319 - val_loss: 0.0406 - val_accuracy: 0.4875
#
# Epoch 49/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0348 - accuracy: 0.2917 - val_loss: 0.0398 - val_accuracy: 0.4625
#
# Epoch 50/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0349 - accuracy: 0.3319 - val_loss: 0.0409 - val_accuracy: 0.4875
#
# Epoch 51/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0350 - accuracy: 0.3431 - val_loss: 0.0405 - val_accuracy: 0.4875
#
# Epoch 52/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0343 - accuracy: 0.2875 - val_loss: 0.0405 - val_accuracy: 0.4875
#
# Epoch 53/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0332 - accuracy: 0.3194 - val_loss: 0.0397 - val_accuracy: 0.4750
#
# Epoch 54/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0334 - accuracy: 0.3194 - val_loss: 0.0390 - val_accuracy: 0.4750
#
# Epoch 55/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0331 - accuracy: 0.3069 - val_loss: 0.0389 - val_accuracy: 0.4625
#
# Epoch 56/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0337 - accuracy: 0.2806 - val_loss: 0.0410 - val_accuracy: 0.4625
#
# Epoch 57/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0375 - accuracy: 0.3444 - val_loss: 0.0408 - val_accuracy: 0.4875
#
# Epoch 58/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0354 - accuracy: 0.3500 - val_loss: 0.0380 - val_accuracy: 0.4625
#
# Epoch 59/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0329 - accuracy: 0.3194 - val_loss: 0.0388 - val_accuracy: 0.4750
#
# Epoch 60/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0331 - accuracy: 0.2917 - val_loss: 0.0373 - val_accuracy: 0.4750
#
# Epoch 61/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0317 - accuracy: 0.2653 - val_loss: 0.0391 - val_accuracy: 0.4875
#
# Epoch 62/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0315 - accuracy: 0.3319 - val_loss: 0.0372 - val_accuracy: 0.4375
#
# Epoch 63/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0321 - accuracy: 0.3083 - val_loss: 0.0406 - val_accuracy: 0.4875
#
# Epoch 64/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0303 - accuracy: 0.2861 - val_loss: 0.0386 - val_accuracy: 0.4875
#
# Epoch 65/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0303 - accuracy: 0.2958 - val_loss: 0.0356 - val_accuracy: 0.4500
#
# Epoch 66/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0306 - accuracy: 0.3097 - val_loss: 0.0360 - val_accuracy: 0.4375
#
# Epoch 67/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0297 - accuracy: 0.2403 - val_loss: 0.0389 - val_accuracy: 0.4750
#
# Epoch 68/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0292 - accuracy: 0.3056 - val_loss: 0.0344 - val_accuracy: 0.4375
#
# Epoch 69/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0291 - accuracy: 0.2486 - val_loss: 0.0391 - val_accuracy: 0.4750
#
# Epoch 70/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0301 - accuracy: 0.2958 - val_loss: 0.0363 - val_accuracy: 0.4375
#
# Epoch 71/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0285 - accuracy: 0.2806 - val_loss: 0.0346 - val_accuracy: 0.4375
#
# Epoch 72/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0297 - accuracy: 0.2264 - val_loss: 0.0372 - val_accuracy: 0.4750
#
# Epoch 73/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0287 - accuracy: 0.3097 - val_loss: 0.0340 - val_accuracy: 0.3750
#
# Epoch 74/100
#
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0285 - accuracy: 0.2167 - val_loss: 0.0372 - val_accuracy: 0.4875
#
# Epoch 75/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0282 - accuracy: 0.2889 - val_loss: 0.0354 - val_accuracy: 0.4375
#
# Epoch 76/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0275 - accuracy: 0.2875 - val_loss: 0.0337 - val_accuracy: 0.4500
#
# Epoch 77/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0283 - accuracy: 0.2500 - val_loss: 0.0356 - val_accuracy: 0.4625
#
# Epoch 78/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0275 - accuracy: 0.2431 - val_loss: 0.0371 - val_accuracy: 0.4875
#
# Epoch 79/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0280 - accuracy: 0.2583 - val_loss: 0.0354 - val_accuracy: 0.4625
#
# Epoch 80/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0270 - accuracy: 0.2681 - val_loss: 0.0348 - val_accuracy: 0.4375
#
# Epoch 81/100
#
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0270 - accuracy: 0.2778 - val_loss: 0.0324 - val_accuracy: 0.4250
#
# Epoch 82/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0267 - accuracy: 0.2542 - val_loss: 0.0347 - val_accuracy: 0.4875
#
# Epoch 83/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0252 - accuracy: 0.2444 - val_loss: 0.0321 - val_accuracy: 0.3750
#
# Epoch 84/100
#
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0258 - accuracy: 0.2458 - val_loss: 0.0313 - val_accuracy: 0.4000
#
# Epoch 85/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0257 - accuracy: 0.2486 - val_loss: 0.0323 - val_accuracy: 0.4000
#
# Epoch 86/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0248 - accuracy: 0.2347 - val_loss: 0.0322 - val_accuracy: 0.4000
#
# Epoch 87/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0251 - accuracy: 0.2347 - val_loss: 0.0327 - val_accuracy: 0.4375
#
# Epoch 88/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0243 - accuracy: 0.2264 - val_loss: 0.0326 - val_accuracy: 0.4125
#
# Epoch 89/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0248 - accuracy: 0.2472 - val_loss: 0.0307 - val_accuracy: 0.3875
#
# Epoch 90/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0244 - accuracy: 0.2431 - val_loss: 0.0309 - val_accuracy: 0.4250
#
# Epoch 91/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0242 - accuracy: 0.2264 - val_loss: 0.0314 - val_accuracy: 0.3750
#
# Epoch 92/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0243 - accuracy: 0.2181 - val_loss: 0.0305 - val_accuracy: 0.3875
#
# Epoch 93/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0236 - accuracy: 0.2264 - val_loss: 0.0315 - val_accuracy: 0.3875
#
# Epoch 94/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0238 - accuracy: 0.2472 - val_loss: 0.0295 - val_accuracy: 0.3625
#
# Epoch 95/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0231 - accuracy: 0.2208 - val_loss: 0.0306 - val_accuracy: 0.4125
#
# Epoch 96/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0227 - accuracy: 0.2208 - val_loss: 0.0300 - val_accuracy: 0.3875
#
# Epoch 97/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0226 - accuracy: 0.2194 - val_loss: 0.0293 - val_accuracy: 0.3625
#
# Epoch 98/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0226 - accuracy: 0.2153 - val_loss: 0.0324 - val_accuracy: 0.4375
#
# Epoch 99/100
#
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0229 - accuracy: 0.2333 - val_loss: 0.0324 - val_accuracy: 0.4375
#
# Epoch 100/100
#
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0222 - accuracy: 0.2028 - val_loss: 0.0323 - val_accuracy: 0.4125

# %% [markdown]
# # Saving the Model

# %%
save_model(model_save_name)

# %% [markdown]
# # Prediction

# %%
image = images_dataset[92] # a random image as test image
test_image_pairs, test_label_pairs = generate_test_image_pairs(images_dataset, labels_dataset, image) # produce an array of test image pairs and test label pairs

# for each pair in the test image pair, predict the similarity between the images
for index, pair in enumerate(test_image_pairs):
    pair_image1 = np.expand_dims(pair[0], axis=-1)
    pair_image1 = np.expand_dims(pair_image1, axis=0)
    pair_image2 = np.expand_dims(pair[1], axis=-1)
    pair_image2 = np.expand_dims(pair_image2, axis=0)
    prediction = model.predict([pair_image1, pair_image2])[0][0]
    display_images(pair[0], pair[1])
    print(prediction,'\n'*3)
# Out:
# 1/1 [==============================] - 0s 110ms/step
# 0.3307843
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 16ms/step
# 0.29806387
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 16ms/step
# 0.2504508
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 23ms/step
# 0.21150108
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 20ms/step
# 0.25137684
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 17ms/step
# 0.13265368
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 16ms/step
# 0.21007249
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 17ms/step
# 0.4261397
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 26ms/step
# 0.20385106
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 17ms/step
# 0.33290175
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 16ms/step
# 0.26681757
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 17ms/step
# 0.17936662
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 21ms/step
# 0.3202617
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 17ms/step
# 0.39259908
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 20ms/step
# 0.23859333
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 17ms/step
# 0.275882
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 16ms/step
# 0.34231916
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 17ms/step
# 0.17487173
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 23ms/step
# 0.23863725
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 24ms/step
# 0.21477003
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 17ms/step
# 0.33599484
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 18ms/step
# 0.5368644
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 16ms/step
# 0.18921551
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 16ms/step
# 0.30988032
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 17ms/step
# 0.22182027
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 16ms/step
# 0.50994205
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 20ms/step
# 0.37656617
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 20ms/step
# 0.46881133
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 19ms/step
# 0.38960993
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 17ms/step
# 0.2481326
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 17ms/step
# 0.3941515
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 18ms/step
# 0.44441262
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 25ms/step
# 0.38603
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 22ms/step
# 0.4570768
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 20ms/step
# 0.2402605
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 23ms/step
# 0.2754262
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 22ms/step
# 0.70208454
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 20ms/step
# 0.29970944
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 21ms/step
# 0.5421168
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 26ms/step
# 0.16644032

# %% [markdown]
# Credits :- Girija Shankar Behera
#
# https://medium.com/wicds/face-recognition-using-siamese-networks-84d6f2e54ea4
